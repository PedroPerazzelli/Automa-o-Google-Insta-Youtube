# %%
import pyautogui
import pyperclip
import time
pyautogui.PAUSE = 1

time.sleep(8)
x, y = pyautogui.position()

# Exibe as coordenadas x e y
print(f' {x}, {y}')
# Out:
#  228, 46

# %%
import pyautogui
import time
import pyperclip

numero_iteracoes = 10

for _ in range(numero_iteracoes):

pyautogui.click( 508, 1061)

time.sleep(1)
pyautogui.click( 37, 9)

def execute_action_multiple_times(action, numero_iteracoes):
    for _ in range(numero_iteracoes):
        # Perform the action in each iteration
        action(1)

def press_down():
    pyautogui.hotkey('down')

# Call the function to execute the action multiple times
execute_action_multiple_times(press_down, 10)

# Code outside the loop
time.sleep(1)
pyautogui.hotkey('down')


time.sleep(1)
pyautogui.hotkey('enter')

time.sleep(1)
pyautogui.click( 228, 46)
time.sleep(1)
pyperclip.copy('https://www.google.com/account/about/?hl=pt-BR')
time.sleep(1)
pyautogui.hotkey('enter')
time.sleep(1)
print("Loop finished")
# Out:
#   Cell In[1], line 9
#     pyautogui.click( 508, 1061)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 7

# %% [markdown]
# vA posição do cursor é: 297, 232
#
#  1068, 1036
#
#
#  1146, 574
#
#  1242, 611
#
#  1396, 577
#
#  1187, 637
#
#  1209, 670
#
#
#  1225, 673
#
#  985, 1000
#
#  1251, 733
#
#
#   1890, 1067
#    1866, 1053

# %%
import pyautogui
import time
import pyperclip




time.sleep(1)
pyautogui.click(1146, 574)
pyautogui.write('jojo')
pyautogui.hotkey('enter')
pyautogui.hotkey('enter')
time.sleep(1)
pyautogui.click(  1145, 573)
time.sleep(1)
pyautogui.hotkey('down')
time.sleep(1)
pyautogui.hotkey('enter')
time.sleep(1)
pyautogui.click( 1238, 579)
time.sleep(1)
pyautogui.write('1999')
time.sleep(1)

pyautogui.click(1396, 567)
time.sleep(1)

pyautogui.write('1999')
time.sleep(1)
pyautogui.click(1440, 748)
time.sleep(1)


pyautogui.click(1225, 673)
time.sleep(1)
pyautogui.click(1251, 733)
time.sleep(1)





pyautogui.scroll(-52)
time.sleep(2)

pyautogui.click(1440, 748)
time.sleep(1)

pyautogui.write('ElectroEclipse45353')

pyautogui.click(1225, 673)
time.sleep(1)


pyautogui.write('ElectroEclipse45353')
time.sleep(1)
pyautogui.hotkey('enter')

pyautogui.write('ElectroEclipse45353')

pyautogui.click( 1225, 564)
time.sleep(1)
pyautogui.write('ElectroEclipse45353')
time.sleep(1)
pyautogui.click(1205, 629)
time.sleep(1)
pyautogui.write('ElectroEclipse45353')
time.sleep(1)
pyautogui.hotkey('enter')

# %%
pyautogui.click(  1145, 573)
time.sleep(0,6)
pyautogui.hotkey('down')
time.sleep(0,6)
pyautogui.hotkey('enter')
time.sleep(0,6)
pyautogui.click( 1238, 579)
time.sleep(0,6)
pyautogui.write('1999')
time.sleep(0,6)
pyautogui.click(1396, 567)
time.sleep(0,6)

pyautogui.write('1999')
time.sleep(0,6)
pyautogui.click( 1134, 632)
time.sleep(0,6)
pyautogui.click(1209, 670)
time.sleep(0,6)

pyautogui.click(1440, 748)
time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 pyautogui.click(  1145, 573)
# ----> 2 time.sleep(0,6)
#       3 pyautogui.hotkey('down')
#       4 time.sleep(0,6)
#
# TypeError: time.sleep() takes exactly one argument (2 given)

# %%
import pyautogui
import time
import pyperclip


pyautogui.click( 508, 1061)

time.sleep(1)
pyautogui.click( 37, 9)

time.sleep(1)
pyautogui.hotkey('down')

time.sleep(1)
pyautogui.hotkey('down')
time.sleep(1)
pyautogui.hotkey('down')
time.sleep(1)
pyautogui.hotkey('enter')

time.sleep(1)
pyautogui.click( 228, 46)
time.sleep(1)
pyperclip.copy('https://www.google.com/account/about/?hl=pt-BR')
time.sleep(1)
pyautogui.hotkey('enter')
time.sleep(1)
pyautogui.click(1146, 574)
time.sleep(1)
pyautogui.write('jojo')
pyautogui.hotkey('enter')
pyautogui.hotkey('enter')
time.sleep(1)
pyautogui.click(  1145, 573)
time.sleep(1)
pyautogui.hotkey('down')
time.sleep(1)
pyautogui.hotkey('enter')
time.sleep(1)
pyautogui.click( 1238, 579)
time.sleep(1)
pyautogui.write('1999')
time.sleep(1)
pyautogui.click(1396, 567)
time.sleep(1)

pyautogui.write('1999')
time.sleep(1)
pyautogui.click( 1134, 632)
time.sleep(1)
pyautogui.click(1209, 670)
time.sleep(1)

pyautogui.click(1440, 748)
time.sleep(1)

pyperclip.copy('ElectroEclipse45353')

pyautogui.hotkey('enter')
pyautogui.click(1225, 673)
time.sleep(1)


pyperclip.copy('ElectroEclipse45353')
time.sleep(1)
pyautogui.hotkey('enter')


time.sleep(1)
pyperclip.copy('ElectroEclipse45353')
time.sleep(1)
pyautogui.click(1205, 629)
time.sleep(1)
pyperclip.copy('ElectroEclipse45353')
time.sleep(2)
pyautogui.hotkey('enter')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 24
#      22 time.sleep(1)
#      23 pyautogui.write('jojo')
# ---> 24 pyautogui.hotkey('enter')
#      25 pyautogui.hotkey('enter')
#      26 time.sleep(1)
#
# File ~\anaconda3\Lib\site-packages\pyautogui\__init__.py:595, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     593 failSafeCheck()
#     594 returnVal = wrappedFunction(*args, **kwargs)
# --> 595 _handlePause(kwargs.get("_pause", True))
#     596 return returnVal
#
# File ~\anaconda3\Lib\site-packages\pyautogui\__init__.py:639, in _handlePause(_pause)
#     637 if _pause:
#     638     assert isinstance(PAUSE, int) or isinstance(PAUSE, float)
# --> 639     time.sleep(PAUSE)
#
# KeyboardInterrupt:
